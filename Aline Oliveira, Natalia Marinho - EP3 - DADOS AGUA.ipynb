# %%
import pandas as pd
import seaborn as sb
low_memory=False
# %matplotlib inline
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
controle = 'controle.csv'
dados = pd.read_csv(controle)

# %%
dados.shape
# Out:
# (752371, 28)

# %%
dados.head(100)
# Out:
#    regiao_geografica sigla_uf regional_de_saude   nome_municipio  codigo_ibge  \
# 0           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 1           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 2           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 3           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 4           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 5           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 6           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 7           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 8           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 9           NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# 10          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA       270240
# ...

# %%
dados.columns
# Out:
# Index(['regiao_geografica', 'sigla_uf', 'regional_de_saude', 'nome_municipio',
#        'codigo_ibge', 'tipo_instituicao', 'sigla_instituicao',
#        'nome_instituicao', 'cnpj_instituicao',
#        'nome_escritorio_regional_local', 'cnpj_escritorio',
#        'tipo_forma_abastecimento', 'codigo_forma_abastecimento',
#        'nome_forma_abastecimento', 'nome_eta', 'ano', 'mes', 'data_registro',
#        'data_preenchimento', 'data_coleta', 'tipo_captacao',
#        'categoria_manancial_sup', 'nome_manancial_sup',
#        'categoria_ponto_cap_sub', 'nome_ponto_cap_sub', 'parametro', 'unidade',
#        'resultado'],
#       dtype='object')

# %%
dados.tail()
# Out:
#        regiao_geografica sigla_uf regional_de_saude   nome_municipio  \
# 752366          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA
# 752367          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA
# 752368          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA
# 752369          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA
# 752370          NORDESTE       AL  10 REGIÃO DEG AL  DELMIRO GOUVEIA
#
#         codigo_ibge  tipo_instituicao sigla_instituicao  \
# 752366       270240  Empresa Estadual             CASAL
# 752367       270240  Empresa Estadual             CASAL
# 752368       270240  Empresa Estadual             CASAL
# 752369       270240  Empresa Estadual             CASAL
# 752370       270240  Empresa Estadual             CASAL
#
#                           nome_instituicao  cnpj_instituicao  \
# 752366  COMPANHIA DE SANEAMENTO DE ALAGOAS      1.229471e+13
# 752367  COMPANHIA DE SANEAMENTO DE ALAGOAS      1.229471e+13
# ...

# %%
dados.sample(10)
# Out:
#        sigla_uf  cnpj_escritorio tipo_forma_abastecimento  \
# 742568       TO     1.199643e+13                      SAA
# 163858       MG     1.728111e+13                      SAA
# 345385       PR     7.648401e+13                      SAA
# 714219       SP              NaN                      SAC
# 25227        BA     1.350468e+13                      SAA
# 225650       MG     1.728111e+13                      SAA
# 122766       GO     1.616929e+12                      SAA
# 13631        BA     1.350468e+13                      SAA
# 669091       SP     4.377652e+13                      SAA
# 578099       SP              NaN                      SAA
#
#        codigo_forma_abastecimento
# 742568              S171750000001
# 163858              S311280000003
# 345385              S411070000004
# 714219              C355650000008
# 25227               S291620000001
# 225650              S316040000001
# 122766              S521450000001
# 13631               S293070000001
# ...

# %%
dados.iloc [567:570]
# Out:
#     regiao_geografica sigla_uf regional_de_saude nome_municipio  codigo_ibge  \
# 567          NORDESTE       AL  10 REGIÃO DEG AL       PIRANHAS       270710
# 568          NORDESTE       AL  10 REGIÃO DEG AL       PIRANHAS       270710
# 569          NORDESTE       AL  10 REGIÃO DEG AL       PIRANHAS       270710
#
#      tipo_instituicao sigla_instituicao                    nome_instituicao  \
# 567  Empresa Estadual             CASAL  COMPANHIA DE SANEAMENTO DE ALAGOAS
# 568  Empresa Estadual             CASAL  COMPANHIA DE SANEAMENTO DE ALAGOAS
# 569  Empresa Estadual             CASAL  COMPANHIA DE SANEAMENTO DE ALAGOAS
#
#      cnpj_instituicao  nome_escritorio_regional_local  cnpj_escritorio  \
# 567      1.229471e+13  UNIDADE SERTAO DELMIRO GOUVEIA     1.229471e+13
# 568      1.229471e+13  UNIDADE SERTAO DELMIRO GOUVEIA     1.229471e+13
# 569      1.229471e+13  UNIDADE SERTAO DELMIRO GOUVEIA     1.229471e+13
#
#     tipo_forma_abastecimento codigo_forma_abastecimento  \
# ...

# %%
dados.data_coleta.values
# Out:
# array(['6/10/2016 00:00:00', '11/10/2016 00:00:00', '20/10/2016 00:00:00',
#        ..., '15/9/2016 00:00:00', '21/9/2016 00:00:00',
#        '29/9/2016 00:00:00'], dtype=object)

# %%
dados.nome_eta.values [5:50]
# Out:
# array(['SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE',
#        'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE', 'SAO JOSE'],
#       dtype=object)

# %%
dados.plot.hist()

# %%
dados.groupby('data_coleta').size().sort_values().tail(20).plot(kind='barh', figsize=(10,10))
